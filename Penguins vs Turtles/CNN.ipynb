# %%
from lib import *
from lable import *
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam, Adamax

# %%
path_train = r"D:\Machine_learning_basic\Penguins vs Turtles\train\train"
path_valid = r'D:\Machine_learning_basic\Penguins vs Turtles\valid\valid'

data_train, label_train = data(path_train)
data_valid, label_valid = data(path_valid)

# %%
visualiztion(data_train)

# %%
data_train_hog = hog_data(data_train)
data_valid_hog = hog_data(data_valid)

# %%
data_train_model = data_label(data_train_hog, label_train)
data_valid_model = data_label(data_valid_hog, label_valid)

# %%
X_train, y_train = train_test_split_(data_train_model)
X_test, y_test = train_test_split_(data_valid_model)

# %%
model = Sequential()
model.add(layers.Input
          (X_train.shape[1]))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(Dense(2,activation='softmax'))

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), # different loss function for multiclass classifcation
                 optimizer=tf.keras.optimizers.Adamax(0.001),
                 metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, batch_size = 5, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 100/100 [==============================] - 2s 8ms/step - loss: 0.5801 - accuracy: 0.7080 - val_loss: 0.7215 - val_accuracy: 0.5833
# Epoch 2/10
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4165 - accuracy: 0.8100 - val_loss: 0.6776 - val_accuracy: 0.6806
# Epoch 3/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3370 - accuracy: 0.8660 - val_loss: 0.5408 - val_accuracy: 0.6528
# Epoch 4/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2922 - accuracy: 0.8660 - val_loss: 0.6366 - val_accuracy: 0.6389
# Epoch 5/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2184 - accuracy: 0.9080 - val_loss: 0.4758 - val_accuracy: 0.7361
# Epoch 6/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2000 - accuracy: 0.9220 - val_loss: 0.5154 - val_accuracy: 0.7500
# Epoch 7/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1293 - accuracy: 0.9520 - val_loss: 0.5202 - val_accuracy: 0.7361
# Epoch 8/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1191 - accuracy: 0.9600 - val_loss: 0.6956 - val_accuracy: 0.7361
# Epoch 9/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0833 - accuracy: 0.9760 - val_loss: 0.6773 - val_accuracy: 0.7222
# Epoch 10/10
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0603 - accuracy: 0.9860 - val_loss: 0.6043 - val_accuracy: 0.7500

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6043 - accuracy: 0.7500
# Test accuracy: 0.75
